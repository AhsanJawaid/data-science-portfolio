# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-genai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
client = genai.Client(api_key='AIzaSyA2ldXPKFL8z_8UOoKlsDfoQDVdJPSf098', http_options={'api_version':'v1alpha'})

# Instead, check for thoughts within the response structure
config = {}

response = client.models.generate_content(
    model='gemini-2.0-flash-thinking-exp',
    contents='Explain in your opinion what field should I select as a career path from Java Full-stack Development, Data Science, DevOps, to start as a fresh career. I`ve 10 years of experience as a PHP Developer, but there is also a 2 years gap in my career',
    config=config
)

# Check if the response contains a 'reasoning' field, which might be equivalent to 'thoughts'
if hasattr(response.candidates[0], 'reasoning'):
    print("Reasoning:", response.candidates[0].reasoning)

# Print the main content of the response
print(response.candidates[0].content)
# Out:
# parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text='It\'s great you\'re looking to pivot your career and explore new technologies!  Let\'s break down these options based on your background and the current tech landscape to help you decide.\n\n**Understanding Your Situation:**\n\n* **10 Years PHP Development:** This is a significant asset! You have a strong foundation in software development principles, likely understand backend logic, databases, APIs, and potentially some frontend concepts even if focused on PHP.  This experience is *not* wasted, even when shifting fields.\n* **2 Year Career Gap:** This is understandable and not uncommon.  It\'s important to address it proactively in your job search, but it doesn\'t negate your 10 years of experience.  Upskilling and demonstrating your current knowledge are key.\n* **Desire for "Fresh Career":** This sugges
# ...
