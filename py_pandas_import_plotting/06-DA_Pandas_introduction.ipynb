# %% [markdown]
# # 6. Pandas Introduction
#
# In the previous chapters, we have learned how to handle Numpy arrays that can be used to efficiently perform numerical calculations. Those arrays are however homogeneous structures i.e. they can only contain one type of data. Also, even if we have a single type of data, the different rows or columns of an array do not have labels, making it difficult to track what they contain. For such cases, we need a structure closer to a table as can be found in Excel, and these structures are implemented by the package Pandas.
#
# But why can't we simply use Excel then? While Excel is practical to browse through data, it is very cumbersome to use to combine, re-arrange and thoroughly analyze data: code is hidden and difficult to share, there's no version control, it's difficult to automate tasks, the manual clicking around leads to mistakes etc.
#
# In the next chapters, you will learn how to handle tabular data with Pandas, a Python package widely used in the scientific and data science areas. You will learn how to create and import tables, how to combine them, modify them, do statistical analysis on them and finally how to use them to easily create complex visualizations.
#
# So that you see where this leads, we start with a short example of how Pandas can be used in a project. We look here at data provided openly by the Swiss National Science Foundation about grants attributed since 1975.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# import url
# projects = pd.read_csv('http://p3.snf.ch/P3Export/P3_GrantExport.csv',sep = ';')

# %% [markdown]
# ## 6.1 Importing data

# %%
# local import
projects = pd.read_csv(r'C:/Users/PMLS/Downloads/P3_GrantExport.csv',sep = ';')

# %% [markdown]
# Then we can have a brief look at the table itself that Jupyter displays in a formated way and limit the view to the 5 first rows using ```head()```:

# %%
projects.head()
# Out:
#    Project Number Project Number String  \
# 0               1           1000-000001
# 1               4           1000-000004
# 2               5           1000-000005
# 3               6           1000-000006
# 4               7           1000-000007
#
#                                        Project Title Project Title English  \
# 0  Schlussband (Bd. VI) der Jacob Burckhardt-Biog...                   NaN
# 1  Batterie de tests à l'usage des enseignants po...                   NaN
# 2  Kritische Erstausgabe der 'Evidentiae contra D...                   NaN
# 3  Katalog der datierten Handschriften in der Sch...                   NaN
# 4  Wissenschaftliche Mitarbeit am Thesaurus Lingu...                   NaN
#
#                                Responsible Applicant  \
# 0                                       Kaegi Werner
# 1                                 Massarenti Léonard
# 2  Kommission für das Corpus philosophorum medii ...
# 3                                     Burckhardt Max
# 4                       Schweiz. Thesauruskommission
#
#              Funding Instrument Funding Instrument Hierarchy  \
# 0  Project funding (Div. I-III)              Project funding
# 1  Project funding (Div. I-III)              Project funding
# 2  Project funding (Div. I-III)              Project funding
# 3  Project funding (Div. I-III)              Project funding
# 4  Project funding (Div. I-III)              Project funding
#
#                                          Institution Institution Country  \
# 0                                                NaN                 NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...         Switzerland
# 2  Kommission für das Corpus philosophorum medii ...         Switzerland
# 3  Abteilung Handschriften und Alte Drucke Univer...         Switzerland
# 4                       Schweiz. Thesauruskommission         Switzerland
#
#                                           University  Discipline Number  \
# 0                                  Unassignable - NA              10302
# 1                          University of Geneva - GE              10104
# 2  Non-profit organisations (libraries, museums, ...              10101
# 3                           University of Basel - BS              10302
# 4  Non-profit organisations (libraries, museums, ...              10303
#
#                          Discipline Name  \
# 0                          Swiss history
# 1       Educational science and Pedagogy
# 2                             Philosophy
# 3                          Swiss history
# 4  Ancient history and Classical studies
#
#                            Discipline Name Hierarchy All disciplines  \
# 0  Humanities and Social Sciences;Theology & reli...           10302
# 1  Humanities and Social Sciences;Psychology, edu...           10104
# 2  Humanities and Social Sciences;Linguistics and...           10101
# 3  Humanities and Social Sciences;Theology & reli...           10302
# 4  Humanities and Social Sciences;Theology & reli...           10303
#
#    Start Date    End Date Approved Amount Keywords
# 0  01.10.1975  30.09.1976        11619.00      NaN
# 1  01.10.1975  30.09.1976        41022.00      NaN
# 2  01.03.1976  28.02.1985        79732.00      NaN
# 3  01.10.1975  30.09.1976        52627.00      NaN
# 4  01.01.1976  30.04.1978       120042.00      NaN

# %%
projects.tail()
# Out:
#        Project Number Project Number String  \
# 74051          196469         31CA30_196469
# 74052          196538         31CA30_196538
# 74053          196615         31CA30_196615
# 74054          196732         31CA30_196732
# 74055          196910         32FI30_196910
#
#                                            Project Title  \
# 74051  Neutralizing multivalent antibodies against co...
# 74052  COWWID-19 | Surveillance of SARS-CoV-2 in Wast...
# 74053  Mixed-method evaluation of an online forward t...
# 74054  How immune responses shape the clinical charac...
# 74055  Swiss SOLIDARITY: An international public heal...
#
#                                    Project Title English  \
# 74051                                                NaN
# 74052  COWWID-19 | Surveillance of SARS-CoV-2 in Wast...
# 74053                                                NaN
# 74054  How immune responses shape the clinical charac...
# 74055  Swiss SOLIDARITY: An international public heal...
#
#       Responsible Applicant  \
# 74051      Plattet Philippe
# 74052         Ort Christoph
# 74053         Sauter Thomas
# 74054  Siegrist Claire-Anne
# 74055          Oriol Manuel
#
#                                       Funding Instrument  \
# 74051  Emergency support for research into corona vir...
# 74052  Emergency support for research into corona vir...
# 74053  Emergency support for research into corona vir...
# 74054  Emergency support for research into corona vir...
# 74055                            Research Infrastructure
#
#                        Funding Instrument Hierarchy  \
# 74051  Programmes;Thematische Sonderausschreibungen
# 74052  Programmes;Thematische Sonderausschreibungen
# 74053  Programmes;Thematische Sonderausschreibungen
# 74054  Programmes;Thematische Sonderausschreibungen
# 74055                                Infrastructure
#
#                                              Institution Institution Country  \
# 74051  Abteilung für Klinische Forschung Dept. für kl...         Switzerland
# 74052  Strategic Environmental Sanitation Planning De...         Switzerland
# 74053  Universitäres Notfallzentrum Inselspital Unive...         Switzerland
# 74054  Département de Pathologie et Immunologie Facul...         Switzerland
# 74055  Service des Maladies Infectieuses Département ...         Switzerland
#
#                                               University  Discipline Number  \
# 74051                           University of Berne - BE              30107
# 74052  Swiss Federal Institute of Aquatic Science and...              30812
# 74053                           University of Berne - BE              30701
# 74054                          University of Geneva - GE              30403
# 74055                        University of Lausanne - LA              30701
#
#                                        Discipline Name  \
# 74051                        Experimental Microbiology
# 74052  Methods of Epidemiology and Preventive Medicine
# 74053                                Internal Medicine
# 74054                      Immunology, Immunopathology
# 74055                                Internal Medicine
#
#                                Discipline Name Hierarchy    All disciplines  \
# 74051     Biology and Medicine;Basic Biological Research        30107/30101
# 74052  Biology and Medicine;Preventive Medicine (Epid...        30812/20709
# 74053             Biology and Medicine;Clinical Medicine  30701/30812/30911
# 74054         Biology and Medicine;Experimental Medicine        30403/30808
# 74055             Biology and Medicine;Clinical Medicine              30701
#
#        Start Date    End Date Approved Amount  \
# 74051  01.06.2020  31.05.2022       301820.00
# 74052  01.06.2020  31.05.2021       182844.00
# 74053  01.06.2020  30.11.2021        99906.00
# 74054  01.06.2020  31.05.2022       298200.00
# 74055  01.04.2020  31.03.2022      1600000.00
#
#                                                 Keywords
# 74051  Multivalent antibody engineering; Neutralizing...
# 74052  virucidal drugs; wastewater-based epidemiology...
# 74053  patient flow; COVID_19; decision support; symp...
# 74054  SARS Coronavirus-2; Disease severity; Innate i...
# 74055                                           Covid-19

# %%
pd.value_counts?

# %% [markdown]
# ## Task: Top 10 Institution count and names

# %%
projects.columns
# Out:
# Index(['Project Number', 'Project Number String', 'Project Title',
#        'Project Title English', 'Responsible Applicant', 'Funding Instrument',
#        'Funding Instrument Hierarchy', 'Institution', 'Institution Country',
#        'University', 'Discipline Number', 'Discipline Name',
#        'Discipline Name Hierarchy', 'All disciplines', 'Start Date',
#        'End Date', 'Approved Amount', 'Keywords'],
#       dtype='object')

# %% [markdown]
# # Data Dimensions (Length and Width/ row and columns)

# %%
print('Number of Rows:',projects.shape[0])
print('Number of Columns:',projects.shape[1])
# Out:
# Number of Rows: 74056
# Number of Columns: 18

# %%
projects['Responsible Applicant'].head()
# Out:
# 0                                         Kaegi Werner
# 1                                   Massarenti Léonard
# 2    Kommission für das Corpus philosophorum medii ...
# 3                                       Burckhardt Max
# 4                         Schweiz. Thesauruskommission
# Name: Responsible Applicant, dtype: object

# %% [markdown]
# ## 6.2 Exploring data
#
# Pandas offers a variety of tools to compile information about data, and that compilation can be done very efficiently without the need for loops, conditionals etc.
#
# For example we can quickly count how many times each University appear in that table. We just use the ```value_counts()``` method for that:

# %%
projects['University'].value_counts()
# Out:
# Institution abroad - IACH                                    13348
# University of Zurich - ZH                                     8170
# University of Geneva - GE                                     7385
# ETH Zurich - ETHZ                                             7278
# University of Berne - BE                                      6445
#                                                              ...
# Staatsunabhängige Theologische Hochschule Basel - STH            3
# Pädagogische Hochschule Schaffhausen - PHSH                      2
# Facoltà di Teologia di Lugano - FTL                              2
# Fernfachhochschule Schweiz (member of SUPSI) - FFHS              2
# Institut de recherche en réadaptation - réinsertion - IRR        1
# Name: University, Length: 84, dtype: int64

# %% [markdown]
# Then we can very easily plot the resulting information, either using directly Pandas or a more advanced library like Seaborn, plotnine or Altair.
#
# Here first with plain Pandas (using Matplotlib under the hood):

# %%
projects['Institution'].value_counts().head(10).plot(kind='pie') #bar
# Out:
# <Axes: ylabel='Institution'>

# %%
projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74056 entries, 0 to 74055
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Project Number                74056 non-null  int64
#  1   Project Number String         74056 non-null  object
#  2   Project Title                 74056 non-null  object
#  3   Project Title English         31108 non-null  object
#  4   Responsible Applicant         74056 non-null  object
#  5   Funding Instrument            74056 non-null  object
#  6   Funding Instrument Hierarchy  74016 non-null  object
#  7   Institution                   68409 non-null  object
#  8   Institution Country           68343 non-null  object
#  9   University                    74051 non-null  object
#  10  Discipline Number             74056 non-null  int64
#  11  Discipline Name               74056 non-null  object
#  12  Discipline Name Hierarchy     73561 non-null  object
#  13  All disciplines               74056 non-null  object
#  14  Start Date                    74054 non-null  object
#  15  End Date                      74054 non-null  object
#  16  Approved Amount               74056 non-null  object
#  17  Keywords                      48946 non-null  object
# dtypes: int64(2), object(16)
# memory usage: 10.2+ MB

# %%
projects.describe()
# Out:
#        Project Number  Discipline Number
# count    74056.000000       74056.000000
# mean     97498.720117       19891.524441
# std      59241.939088        8264.082527
# min          1.000000           0.000000
# 25%      41919.750000       10401.000000
# 50%     111845.000000       20404.000000
# 75%     147669.000000       30103.000000
# max     196910.000000       50000.000000

# %%
projects.isnull().sum()
# Out:
# Project Number                      0
# Project Number String               0
# Project Title                       0
# Project Title English           42948
# Responsible Applicant               0
# Funding Instrument                  0
# Funding Instrument Hierarchy       40
# Institution                      5647
# Institution Country              5713
# University                          5
# Discipline Number                   0
# Discipline Name                     0
# Discipline Name Hierarchy         495
# All disciplines                     0
# Start Date                          2
# End Date                            2
# Approved Amount                     0
# Keywords                        25110
# dtype: int64

# %% [markdown]
# ## 6.3 Handling different data types
#
# Unlike Numpy arrays, Pandas can handle a variety of different data types in a dataframe. For example it is very efficient at dealing with dates. We see that our table contains e.g. a ```Start Date```. We can turn this string into an actual date:

# %%
projects['Start Date'] = pd.to_datetime(projects['Start Date'])
projects['End Date'] = pd.to_datetime(projects['End Date'])
projects['year']= pd.to_datetime(projects['Start Date']).dt.year

# %%
projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74056 entries, 0 to 74055
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Project Number                74056 non-null  int64
#  1   Project Number String         74056 non-null  object
#  2   Project Title                 74056 non-null  object
#  3   Project Title English         31108 non-null  object
#  4   Responsible Applicant         74056 non-null  object
#  5   Funding Instrument            74056 non-null  object
#  6   Funding Instrument Hierarchy  74016 non-null  object
#  7   Institution                   68409 non-null  object
#  8   Institution Country           68343 non-null  object
#  9   University                    74051 non-null  object
#  10  Discipline Number             74056 non-null  int64
#  11  Discipline Name               74056 non-null  object
#  12  Discipline Name Hierarchy     73561 non-null  object
#  13  All disciplines               74056 non-null  object
#  14  Start Date                    74054 non-null  datetime64[ns]
#  15  End Date                      74054 non-null  datetime64[ns]
#  16  Approved Amount               61038 non-null  float64
#  17  Keywords                      48946 non-null  object
#  18  Field                         73561 non-null  object
#  19  year                          74054 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(2), object(14)
# memory usage: 11.3+ MB

# %%
projects.columns
# Out:
# Index(['Project Number', 'Project Number String', 'Project Title',
#        'Project Title English', 'Responsible Applicant', 'Funding Instrument',
#        'Funding Instrument Hierarchy', 'Institution', 'Institution Country',
#        'University', 'Discipline Number', 'Discipline Name',
#        'Discipline Name Hierarchy', 'All disciplines', 'Start Date',
#        'End Date', 'Approved Amount', 'Keywords', 'start', 'year'],
#       dtype='object')

# %%
projects.drop('year', axis = 1, inplace = True)
# Out:
#        Project Number Project Number String  \
# 0                   1           1000-000001
# 1                   4           1000-000004
# 2                   5           1000-000005
# 3                   6           1000-000006
# 4                   7           1000-000007
# ...               ...                   ...
# 74051          196469         31CA30_196469
# 74052          196538         31CA30_196538
# 74053          196615         31CA30_196615
# 74054          196732         31CA30_196732
# 74055          196910         32FI30_196910
#
#                                            Project Title  \
# 0      Schlussband (Bd. VI) der Jacob Burckhardt-Biog...
# 1      Batterie de tests à l'usage des enseignants po...
# 2      Kritische Erstausgabe der 'Evidentiae contra D...
# 3      Katalog der datierten Handschriften in der Sch...
# 4      Wissenschaftliche Mitarbeit am Thesaurus Lingu...
# ...                                                  ...
# 74051  Neutralizing multivalent antibodies against co...
# 74052  COWWID-19 | Surveillance of SARS-CoV-2 in Wast...
# 74053  Mixed-method evaluation of an online forward t...
# 74054  How immune responses shape the clinical charac...
# 74055  Swiss SOLIDARITY: An international public heal...
#
#                                    Project Title English  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 74051                                                NaN
# 74052  COWWID-19 | Surveillance of SARS-CoV-2 in Wast...
# 74053                                                NaN
# 74054  How immune responses shape the clinical charac...
# 74055  Swiss SOLIDARITY: An international public heal...
#
#                                    Responsible Applicant  \
# 0                                           Kaegi Werner
# 1                                     Massarenti Léonard
# 2      Kommission für das Corpus philosophorum medii ...
# 3                                         Burckhardt Max
# 4                           Schweiz. Thesauruskommission
# ...                                                  ...
# 74051                                   Plattet Philippe
# 74052                                      Ort Christoph
# 74053                                      Sauter Thomas
# 74054                               Siegrist Claire-Anne
# 74055                                       Oriol Manuel
#
#                                       Funding Instrument  \
# 0                           Project funding (Div. I-III)
# 1                           Project funding (Div. I-III)
# 2                           Project funding (Div. I-III)
# 3                           Project funding (Div. I-III)
# 4                           Project funding (Div. I-III)
# ...                                                  ...
# 74051  Emergency support for research into corona vir...
# 74052  Emergency support for research into corona vir...
# 74053  Emergency support for research into corona vir...
# 74054  Emergency support for research into corona vir...
# 74055                            Research Infrastructure
#
#                        Funding Instrument Hierarchy  \
# 0                                   Project funding
# 1                                   Project funding
# 2                                   Project funding
# 3                                   Project funding
# 4                                   Project funding
# ...                                             ...
# 74051  Programmes;Thematische Sonderausschreibungen
# 74052  Programmes;Thematische Sonderausschreibungen
# 74053  Programmes;Thematische Sonderausschreibungen
# 74054  Programmes;Thematische Sonderausschreibungen
# 74055                                Infrastructure
#
#                                              Institution Institution Country  \
# 0                                                    NaN                 NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...         Switzerland
# 2      Kommission für das Corpus philosophorum medii ...         Switzerland
# 3      Abteilung Handschriften und Alte Drucke Univer...         Switzerland
# 4                           Schweiz. Thesauruskommission         Switzerland
# ...                                                  ...                 ...
# 74051  Abteilung für Klinische Forschung Dept. für kl...         Switzerland
# 74052  Strategic Environmental Sanitation Planning De...         Switzerland
# 74053  Universitäres Notfallzentrum Inselspital Unive...         Switzerland
# 74054  Département de Pathologie et Immunologie Facul...         Switzerland
# 74055  Service des Maladies Infectieuses Département ...         Switzerland
#
#                                               University  Discipline Number  \
# 0                                      Unassignable - NA              10302
# 1                              University of Geneva - GE              10104
# 2      Non-profit organisations (libraries, museums, ...              10101
# 3                               University of Basel - BS              10302
# 4      Non-profit organisations (libraries, museums, ...              10303
# ...                                                  ...                ...
# 74051                           University of Berne - BE              30107
# 74052  Swiss Federal Institute of Aquatic Science and...              30812
# 74053                           University of Berne - BE              30701
# 74054                          University of Geneva - GE              30403
# 74055                        University of Lausanne - LA              30701
#
#                                        Discipline Name  \
# 0                                        Swiss history
# 1                     Educational science and Pedagogy
# 2                                           Philosophy
# 3                                        Swiss history
# 4                Ancient history and Classical studies
# ...                                                ...
# 74051                        Experimental Microbiology
# 74052  Methods of Epidemiology and Preventive Medicine
# 74053                                Internal Medicine
# 74054                      Immunology, Immunopathology
# 74055                                Internal Medicine
#
#                                Discipline Name Hierarchy    All disciplines  \
# 0      Humanities and Social Sciences;Theology & reli...              10302
# 1      Humanities and Social Sciences;Psychology, edu...              10104
# 2      Humanities and Social Sciences;Linguistics and...              10101
# 3      Humanities and Social Sciences;Theology & reli...              10302
# 4      Humanities and Social Sciences;Theology & reli...              10303
# ...                                                  ...                ...
# 74051     Biology and Medicine;Basic Biological Research        30107/30101
# 74052  Biology and Medicine;Preventive Medicine (Epid...        30812/20709
# 74053             Biology and Medicine;Clinical Medicine  30701/30812/30911
# 74054         Biology and Medicine;Experimental Medicine        30403/30808
# 74055             Biology and Medicine;Clinical Medicine              30701
#
#       Start Date   End Date Approved Amount
# 0     1975-01-10 1976-09-30        11619.00
# 1     1975-01-10 1976-09-30        41022.00
# 2     1976-01-03 1985-02-28        79732.00
# 3     1975-01-10 1976-09-30        52627.00
# 4     1976-01-01 1978-04-30       120042.00
# ...          ...        ...             ...
# 74051 2020-01-06 2022-05-31       301820.00
# 74052 2020-01-06 2021-05-31       182844.00
# 74053 2020-01-06 2021-11-30        99906.00
# 74054 2020-01-06 2022-05-31       298200.00
# 74055 2020-01-04 2022-03-31      1600000.00
#
# [74056 rows x 17 columns]

# %%
projects.head()
# Out:
#    Project Number Project Number String  \
# 0               1           1000-000001
# 1               4           1000-000004
# 2               5           1000-000005
# 3               6           1000-000006
# 4               7           1000-000007
#
#                                        Project Title Project Title English  \
# 0  Schlussband (Bd. VI) der Jacob Burckhardt-Biog...                   NaN
# 1  Batterie de tests à l'usage des enseignants po...                   NaN
# 2  Kritische Erstausgabe der 'Evidentiae contra D...                   NaN
# 3  Katalog der datierten Handschriften in der Sch...                   NaN
# 4  Wissenschaftliche Mitarbeit am Thesaurus Lingu...                   NaN
#
#                                Responsible Applicant  \
# 0                                       Kaegi Werner
# 1                                 Massarenti Léonard
# 2  Kommission für das Corpus philosophorum medii ...
# 3                                     Burckhardt Max
# 4                       Schweiz. Thesauruskommission
#
#              Funding Instrument Funding Instrument Hierarchy  \
# 0  Project funding (Div. I-III)              Project funding
# 1  Project funding (Div. I-III)              Project funding
# 2  Project funding (Div. I-III)              Project funding
# 3  Project funding (Div. I-III)              Project funding
# 4  Project funding (Div. I-III)              Project funding
#
#                                          Institution Institution Country  \
# 0                                                NaN                 NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...         Switzerland
# 2  Kommission für das Corpus philosophorum medii ...         Switzerland
# 3  Abteilung Handschriften und Alte Drucke Univer...         Switzerland
# 4                       Schweiz. Thesauruskommission         Switzerland
#
#                                           University  Discipline Number  \
# 0                                  Unassignable - NA              10302
# 1                          University of Geneva - GE              10104
# 2  Non-profit organisations (libraries, museums, ...              10101
# 3                           University of Basel - BS              10302
# 4  Non-profit organisations (libraries, museums, ...              10303
#
#                          Discipline Name  \
# 0                          Swiss history
# 1       Educational science and Pedagogy
# 2                             Philosophy
# 3                          Swiss history
# 4  Ancient history and Classical studies
#
#                            Discipline Name Hierarchy All disciplines  \
# 0  Humanities and Social Sciences;Theology & reli...           10302
# 1  Humanities and Social Sciences;Psychology, edu...           10104
# 2  Humanities and Social Sciences;Linguistics and...           10101
# 3  Humanities and Social Sciences;Theology & reli...           10302
# 4  Humanities and Social Sciences;Theology & reli...           10303
#
#   Start Date   End Date Approved Amount Keywords
# 0 1975-01-10 1976-09-30        11619.00      NaN
# 1 1975-01-10 1976-09-30        41022.00      NaN
# 2 1976-01-03 1985-02-28        79732.00      NaN
# 3 1975-01-10 1976-09-30        52627.00      NaN
# 4 1976-01-01 1978-04-30       120042.00      NaN

# %%
projects.columns
# Out:
# Index(['Project Number', 'Project Number String', 'Project Title',
#        'Project Title English', 'Responsible Applicant', 'Funding Instrument',
#        'Funding Instrument Hierarchy', 'Institution', 'Institution Country',
#        'University', 'Discipline Number', 'Discipline Name',
#        'Discipline Name Hierarchy', 'All disciplines', 'Start Date',
#        'End Date', 'Approved Amount', 'Keywords'],
#       dtype='object')

# %%
projects['Funding Instrument'].value_counts().head()
# Out:
# Project funding (Div. I-III)               35413
# Fellowships for prospective researchers     6485
# Publication grants                          3695
# Scientific Conferences                      3514
# Early Postdoc.Mobility                      2286
# Name: Funding Instrument, dtype: int64

# %%
projects.loc[0:15]
# Out:
#     Project Number Project Number String  \
# 0                1           1000-000001
# 1                4           1000-000004
# 2                5           1000-000005
# 3                6           1000-000006
# 4                7           1000-000007
# 5                8           1000-000008
# 6                9           1000-000009
# 7               10           1000-000010
# 8               11           1000-000011
# 9               13           1000-000013
# 10              14           1000-000014
# 11              17           1000-000017
# 12              18           1000-000018
# 13              19           1000-000019
# 14              20           1000-000020
# 15              21           1000-000021
#
#                                         Project Title Project Title English  \
# 0   Schlussband (Bd. VI) der Jacob Burckhardt-Biog...                   NaN
# 1   Batterie de tests à l'usage des enseignants po...                   NaN
# 2   Kritische Erstausgabe der 'Evidentiae contra D...                   NaN
# 3   Katalog der datierten Handschriften in der Sch...                   NaN
# 4   Wissenschaftliche Mitarbeit am Thesaurus Lingu...                   NaN
# 5   Die schweizerische Wirtschaftspolitik seit dem...                   NaN
# 6   Theologische Forschungen zur Oekumene (Studien...                   NaN
# 7   Konfuzianische Kulturwerte in der sozialen Ent...                   NaN
# 8   Edizione degli scritti di Aurelio de' Giorgi B...                   NaN
# 9   La construction de nouveautés au sein des morp...                   NaN
# 10  Wissensstruktur, Fragegenese und Wissenserweit...                   NaN
# 11  Rechtsquellenkommission des Schweizerischen Ju...                   NaN
# 12  L'école et la vie: examens pédagogiques des re...                   NaN
# 13    Das Ringen um soziale Sicherheit in der Schweiz                   NaN
# 14  Kolloquium zum Thema 'Ein System Sozialer Indi...                   NaN
# 15  Struktur und Funktion didaktischer Bezugssyste...                   NaN
#
#                                 Responsible Applicant  \
# 0                                        Kaegi Werner
# 1                                  Massarenti Léonard
# 2   Kommission für das Corpus philosophorum medii ...
# 3                                      Burckhardt Max
# 4                        Schweiz. Thesauruskommission
# 5                                 Kleinewefers Henner
# 6                                 Stirnimann Heinrich
# 7                                    Deuchler Martina
# 8                                     Stäuble Antonio
# 9                                         Piaget Jean
# 10                                     Flammer August
# 11  Schweizerische Rechtsquellen c/o Universität Z...
# 12                                        Girod Roger
# 13                                      Borner Silvio
# 14                      Hoffmann-Nowotny Hans-Joachim
# 15                                      Santini Bruno
#
#               Funding Instrument Funding Instrument Hierarchy  \
# 0   Project funding (Div. I-III)              Project funding
# 1   Project funding (Div. I-III)              Project funding
# 2   Project funding (Div. I-III)              Project funding
# 3   Project funding (Div. I-III)              Project funding
# 4   Project funding (Div. I-III)              Project funding
# 5   Project funding (Div. I-III)              Project funding
# 6   Project funding (Div. I-III)              Project funding
# 7   Project funding (Div. I-III)              Project funding
# 8   Project funding (Div. I-III)              Project funding
# 9   Project funding (Div. I-III)              Project funding
# 10  Project funding (Div. I-III)              Project funding
# 11  Project funding (Div. I-III)              Project funding
# 12  Project funding (Div. I-III)              Project funding
# 13  Project funding (Div. I-III)              Project funding
# 14  Project funding (Div. I-III)              Project funding
# 15  Project funding (Div. I-III)              Project funding
#
#                                           Institution Institution Country  \
# 0                                                 NaN                 NaN
# 1   Faculté de Psychologie et des Sciences de l'Ed...         Switzerland
# 2   Kommission für das Corpus philosophorum medii ...         Switzerland
# 3   Abteilung Handschriften und Alte Drucke Univer...         Switzerland
# 4                        Schweiz. Thesauruskommission         Switzerland
# 5   Séminaire de politique économique, d'économie ...         Switzerland
# 6   Institut für ökumenische Studien Université de...         Switzerland
# 7           Ostasiatisches Seminar Universität Zürich         Switzerland
# 8                                                 NaN                 NaN
# 9   Laboratoire de Didactique et Epistémologie des...         Switzerland
# 10  Klinische Psychologie und Psychotherapie Insti...         Switzerland
# 11  Schweizerische Rechtsquellen c/o Universität Z...         Switzerland
# 12  Département de Sociologie Faculté des Sciences...         Switzerland
# 13  Institut für Volkswirtschaft WWZ / FGS Univers...         Switzerland
# 14         Soziologisches Institut Universität Zürich         Switzerland
# 15                              Forschungszentrum FAL         Switzerland
#
#                                            University  Discipline Number  \
# 0                                   Unassignable - NA              10302
# 1                           University of Geneva - GE              10104
# 2   Non-profit organisations (libraries, museums, ...              10101
# 3                            University of Basel - BS              10302
# 4   Non-profit organisations (libraries, museums, ...              10303
# 5                         University of Fribourg - FR              10203
# 6                         University of Fribourg - FR              10102
# 7                           University of Zurich - ZH              10301
# 8                         University of Lausanne - LA              10502
# 9                           University of Geneva - GE              10105
# 10                        University of Fribourg - FR              10105
# 11  Non-profit organisations (libraries, museums, ...              10205
# 12                          University of Geneva - GE              10201
# 13                           University of Basel - BS              10203
# 14                          University of Zurich - ZH              10201
# 15                        University of Fribourg - FR              10104
#
#                                     Discipline Name  \
# 0                                     Swiss history
# 1                  Educational science and Pedagogy
# 2                                        Philosophy
# 3                                     Swiss history
# 4             Ancient history and Classical studies
# 5                                         Economics
# 6                       Religious studies, Theology
# 7   General history (without pre-and early history)
# 8                  Romance languages and literature
# 9                                        Psychology
# 10                                       Psychology
# 11                                   Legal sciences
# 12                                        Sociology
# 13                                        Economics
# 14                                        Sociology
# 15                 Educational science and Pedagogy
#
#                             Discipline Name Hierarchy All disciplines  \
# 0   Humanities and Social Sciences;Theology & reli...           10302
# 1   Humanities and Social Sciences;Psychology, edu...           10104
# 2   Humanities and Social Sciences;Linguistics and...           10101
# 3   Humanities and Social Sciences;Theology & reli...           10302
# 4   Humanities and Social Sciences;Theology & reli...           10303
# 5       Humanities and Social Sciences;Economics, law           10203
# 6   Humanities and Social Sciences;Theology & reli...           10102
# 7   Humanities and Social Sciences;Theology & reli...           10301
# 8   Humanities and Social Sciences;Linguistics and...           10502
# 9   Humanities and Social Sciences;Psychology, edu...           10105
# 10  Humanities and Social Sciences;Psychology, edu...           10105
# 11      Humanities and Social Sciences;Economics, law           10205
# 12  Humanities and Social Sciences;Sociology, soci...           10201
# 13      Humanities and Social Sciences;Economics, law           10203
# 14  Humanities and Social Sciences;Sociology, soci...           10201
# 15  Humanities and Social Sciences;Psychology, edu...           10104
#
#    Start Date   End Date Approved Amount Keywords
# 0  1975-01-10 1976-09-30        11619.00      NaN
# 1  1975-01-10 1976-09-30        41022.00      NaN
# 2  1976-01-03 1985-02-28        79732.00      NaN
# 3  1975-01-10 1976-09-30        52627.00      NaN
# 4  1976-01-01 1978-04-30       120042.00      NaN
# 5  1976-01-01 1978-12-31        53009.00      NaN
# 6  1976-01-01 1976-12-31        25403.00      NaN
# 7  1975-01-10 1977-03-31        47100.00      NaN
# 8  1975-01-10 1977-03-31        25814.00      NaN
# 9  1975-01-10 1978-09-30       360000.00      NaN
# 10 1975-01-10 1978-12-31       153886.00      NaN
# 11 1975-01-10 1978-09-30       862200.00      NaN
# 12 1975-01-10 1977-09-30       116991.00      NaN
# 13 1975-01-10 1978-12-31       112664.00      NaN
# 14 1975-01-10 1975-12-31         5000.00      NaN
# 15 1975-01-10 1977-09-30       204018.00      NaN

# %%
projects.loc[0].year
# Out:
# 1975.0

# %% [markdown]
# ## 6.4 Data wrangling, aggregation and statistics
#
# Pandas is very efficient at wrangling and aggregating data, i.e. grouping several elements of a table to calculate statistics on them. For example we first need here to convert the ```Approved Amount``` to a numeric value. Certain rows contain text (e.g. "not applicable") and we force the conversion:

# %%
projects['Approved Amount'] = pd.to_numeric(projects['Approved Amount'], errors = 'coerce')

# %% [markdown]
# Then we want to extract the type of filed without subfields e.g. "Humanities" instead of "Humanities and Social Sciences;Theology & religion". For that we can create a custom function and apply it to an entire column:

# %%
projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74056 entries, 0 to 74055
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Project Number                74056 non-null  int64
#  1   Project Number String         74056 non-null  object
#  2   Project Title                 74056 non-null  object
#  3   Project Title English         31108 non-null  object
#  4   Responsible Applicant         74056 non-null  object
#  5   Funding Instrument            74056 non-null  object
#  6   Funding Instrument Hierarchy  74016 non-null  object
#  7   Institution                   68409 non-null  object
#  8   Institution Country           68343 non-null  object
#  9   University                    74051 non-null  object
#  10  Discipline Number             74056 non-null  int64
#  11  Discipline Name               74056 non-null  object
#  12  Discipline Name Hierarchy     73561 non-null  object
#  13  All disciplines               74056 non-null  object
#  14  Start Date                    74054 non-null  datetime64[ns]
#  15  End Date                      74054 non-null  datetime64[ns]
#  16  Approved Amount               61038 non-null  float64
#  17  Keywords                      48946 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(13)
# memory usage: 10.2+ MB

# %%
projects.describe()
# Out:
#        Project Number  Discipline Number  Approved Amount
# count    74056.000000       74056.000000     6.103800e+04
# mean     97498.720117       19891.524441     2.843398e+05
# std      59241.939088        8264.082527     5.680805e+05
# min          1.000000           0.000000     0.000000e+00
# 25%      41919.750000       10401.000000     6.071925e+04
# 50%     111845.000000       20404.000000     1.800000e+05
# 75%     147669.000000       30103.000000     3.437110e+05
# max     196910.000000       50000.000000     2.070392e+07

# %%
science_types = ['Humanities', 'Mathematics','Biology']
projects['Field'] = projects['Discipline Name Hierarchy'].apply(
    lambda el: next((y for y in [x for x in science_types if x in el] if y is not None),None) if not pd.isna(el) else el)

# %%
projects.head(100)
# Out:
#     Project Number Project Number String  \
# 0                1           1000-000001
# 1                4           1000-000004
# 2                5           1000-000005
# 3                6           1000-000006
# 4                7           1000-000007
# ..             ...                   ...
# 95             121           1000-000121
# 96             122           1000-000122
# 97             123           1000-000123
# 98             125           1000-000125
# 99             126           1000-000126
#
#                                         Project Title Project Title English  \
# 0   Schlussband (Bd. VI) der Jacob Burckhardt-Biog...                   NaN
# 1   Batterie de tests à l'usage des enseignants po...                   NaN
# 2   Kritische Erstausgabe der 'Evidentiae contra D...                   NaN
# 3   Katalog der datierten Handschriften in der Sch...                   NaN
# 4   Wissenschaftliche Mitarbeit am Thesaurus Lingu...                   NaN
# ..                                                ...                   ...
# 95  Forschungen zur Geschichte und Kunstgeschichte...                   NaN
# 96  Correspondance de Henry Dunant (Réunion de l'e...                   NaN
# 97  Recherches et rédaction d'un ouvrage sur l' 'H...                   NaN
# 98  Fouilles archéologiques coptes aux KELLIA (Egy...                   NaN
# 99  Etude sur l'évolution des valeurs de Molière a...                   NaN
#
#                                 Responsible Applicant  \
# 0                                        Kaegi Werner
# 1                                  Massarenti Léonard
# 2   Kommission für das Corpus philosophorum medii ...
# 3                                      Burckhardt Max
# 4                        Schweiz. Thesauruskommission
# ..                                                ...
# 95           Stift. Pro Kloster St. Johann in Müstair
# 96                                   Gagnebin Bernard
# 97                                    Nicoulin Martin
# 98                                    Kasser Rodolphe
# 99                                   Francillon Roger
#
#               Funding Instrument Funding Instrument Hierarchy  \
# 0   Project funding (Div. I-III)              Project funding
# 1   Project funding (Div. I-III)              Project funding
# 2   Project funding (Div. I-III)              Project funding
# 3   Project funding (Div. I-III)              Project funding
# 4   Project funding (Div. I-III)              Project funding
# ..                           ...                          ...
# 95  Project funding (Div. I-III)              Project funding
# 96  Project funding (Div. I-III)              Project funding
# 97  Project funding (Div. I-III)              Project funding
# 98  Project funding (Div. I-III)              Project funding
# 99  Project funding (Div. I-III)              Project funding
#
#                                           Institution Institution Country  \
# 0                                                 NaN                 NaN
# 1   Faculté de Psychologie et des Sciences de l'Ed...         Switzerland
# 2   Kommission für das Corpus philosophorum medii ...         Switzerland
# 3   Abteilung Handschriften und Alte Drucke Univer...         Switzerland
# 4                        Schweiz. Thesauruskommission         Switzerland
# ..                                                ...                 ...
# 95           Stift. Pro Kloster St. Johann in Müstair         Switzerland
# 96                                                NaN                 NaN
# 97                  Schweizerische Nationalbibliothek         Switzerland
# 98  Département des sciences de l'antiquité Facult...         Switzerland
# 99             Romanisches Seminar Universität Zürich         Switzerland
#
#                                            University  Discipline Number  \
# 0                                   Unassignable - NA              10302
# 1                           University of Geneva - GE              10104
# 2   Non-profit organisations (libraries, museums, ...              10101
# 3                            University of Basel - BS              10302
# 4   Non-profit organisations (libraries, museums, ...              10303
# ..                                                ...                ...
# 95  Non-profit organisations (libraries, museums, ...              10404
# 96                          University of Geneva - GE              10302
# 97  Non-profit organisations (libraries, museums, ...              10302
# 98                          University of Geneva - GE              10402
# 99                        University of Lausanne - LA              10502
#
#                           Discipline Name  \
# 0                           Swiss history
# 1        Educational science and Pedagogy
# 2                              Philosophy
# 3                           Swiss history
# 4   Ancient history and Classical studies
# ..                                    ...
# 95            Visual arts and Art history
# 96                          Swiss history
# 97                          Swiss history
# 98                            Archaeology
# 99       Romance languages and literature
#
#                             Discipline Name Hierarchy All disciplines  \
# 0   Humanities and Social Sciences;Theology & reli...           10302
# 1   Humanities and Social Sciences;Psychology, edu...           10104
# 2   Humanities and Social Sciences;Linguistics and...           10101
# 3   Humanities and Social Sciences;Theology & reli...           10302
# 4   Humanities and Social Sciences;Theology & reli...           10303
# ..                                                ...             ...
# 95  Humanities and Social Sciences;Art studies, mu...           10404
# 96  Humanities and Social Sciences;Theology & reli...           10302
# 97  Humanities and Social Sciences;Theology & reli...           10302
# 98  Humanities and Social Sciences;Theology & reli...           10402
# 99  Humanities and Social Sciences;Linguistics and...           10502
#
#    Start Date   End Date  Approved Amount Keywords       Field
# 0  1975-01-10 1976-09-30          11619.0      NaN  Humanities
# 1  1975-01-10 1976-09-30          41022.0      NaN  Humanities
# 2  1976-01-03 1985-02-28          79732.0      NaN  Humanities
# 3  1975-01-10 1976-09-30          52627.0      NaN  Humanities
# 4  1976-01-01 1978-04-30         120042.0      NaN  Humanities
# ..        ...        ...              ...      ...         ...
# 95 1976-01-04 1979-05-31        1062788.0      NaN  Humanities
# 96 1976-01-04 1978-03-31          55927.0      NaN  Humanities
# 97 1976-01-04 1977-05-31          29420.0      NaN  Humanities
# 98 1976-01-04 1977-06-30         139988.0      NaN  Humanities
# 99 1976-01-06 1979-05-31          17000.0      NaN  Humanities
#
# [100 rows x 19 columns]

# %% [markdown]
# Then we group the data by discipline and year, and calculate the mean of each group:

# %%
aggregated = projects.groupby(['Institution Country','Start Date','Field'], as_index=False).mean()
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_16888\214191481.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   aggregated = projects.groupby(['Institution Country','Start Date','Field'], as_index=False).mean()

# %% [markdown]
# Finally we can use Seaborn to plot the data by "Field" using just keywords to indicate what the axes and colours should mean (following some principles of the grammar of graphics):

# %%
sns.lineplot(data = aggregated, x = 'Start Date', y='Approved Amount', hue='Field');

# %% [markdown]
# Note that here, axis labelling, colorouring, legend, interval of confidence have been done automatically based on the content of the dataframe.
#
# We see a drastic augmentation around 2010: let's have a closer look. We can here again group data by year and funding type and calculate the total funding:

# %%
grouped = projects.groupby(['year','Funding Instrument Hierarchy']).agg(
    total_sum=pd.NamedAgg(column='Approved Amount', aggfunc='sum')).reset_index()

# %%
grouped
# Out:
#        year                       Funding Instrument Hierarchy    total_sum
# 0    1975.0                                    Project funding   32124534.0
# 1    1975.0                              Science communication      44600.0
# 2    1976.0     Programmes;National Research Programmes (NRPs)     268812.0
# 3    1976.0                                    Project funding   96620284.0
# 4    1976.0                              Science communication     126939.0
# ..      ...                                                ...          ...
# 378  2020.0  Programmes;r4d (Swiss Programme for Research o...     195910.0
# 379  2020.0                                    Project funding  193568294.0
# 380  2020.0          Project funding;Project funding (special)   19239681.0
# 381  2020.0                              Science communication    3451740.0
# 382  2021.0                              Science communication      55200.0
#
# [383 rows x 3 columns]

# %% [markdown]
# Now, for each year we keep only the 5 largest funding types to be able to plot them:

# %%
group_sorted = grouped.groupby('year',as_index=False).apply(lambda x: (x.groupby('Funding Instrument Hierarchy')
                                      .sum()
                                      .sort_values('total_sum', ascending=False))
                                     .head(5)).reset_index()

# %% [markdown]
# Finally, we only keep year in the 2000's:

# %%
instruments_by_year = group_sorted[(group_sorted.year > 2005) & (group_sorted.year < 2012)]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.barplot(data=instruments_by_year,
            x='year', y='total_sum', hue='Funding Instrument Hierarchy')
# Out:
# <Axes: xlabel='year', ylabel='total_sum'>

# %% [markdown]
# We see that the main change, is the sudden increase in funding for national research programs.
