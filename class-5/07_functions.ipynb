# %% [markdown]
# # Functions

# %%
def sohail_data(): #no parametrized function
    name = 'Sohail'
    age = 24
    sal = 4000
    qualification = 'MS-DS'
    
    print(f"My Name is {name}, and I am {age} years old. I have a basic salary of {sal}, and my qualifications are {qualification}")

# %%
sohail_data()
# Out:
# My Name is Sohail, and I am 24 years old. I have a basic salary of 4000, and my qualifications are MS-DS

# %%
sohail_data()
# Out:
# Enter your name:  Azhar
# Your age 24
# Enter your Salary100
# Your Highest QualificationsMBA
# My Name is Azhar, and I am 24 years old. I have a basic salary of 100, and my qualifications are MBA

# %%
my_info =['1','1','1','1','1']
def sohail_data(): #no parametrized function
    name = input('Enter your name:  ')
    age = int(input('Your age  '))
    sal = int(input('Enter your Salary  '))
    qualification = input('Your Highest Qualifications  ')
#     3 other variable 
    
    my_info[0]=name
    my_info[1]=age
    my_info[2]=sal
    my_info[3]=qualification


    print(f"My Name is {name}, and I am {age} years old. I have a basic salary of {sal}, and my qualifications are {qualification}")
    
print('out of function')
# Out:
# out of function

# %%
sohail_data()

# %%
def my_info():
    name = input('Enter your name  ')
    age = int(input('Enter your age '))
    dept = input('Enter your department ')
    
    print(f"My name is {name} and I am {age} years old, I am in {dept} department")
    
def my_marks():
    math = int(input('Enter your Math Marks '))
    cs = int(input('Enter your CS Marks'))
    Eng = int (input('Your English Marks '))
    
    print(f"My marks in mathematics are {math} my marks in CS are {cs} and in English its {Eng}")


my_funct = [my_info, my_marks]

# %%
for i in my_funct:
    i()
    print('__________________________________________________________')
# Out:
# Enter your name  Sohail
# Enter your age 12
# Enter your department AI
# My name is Sohail and I am 12 years old, I am in AI department
# __________________________________________________________
# Enter your Math Marks 12
# Enter your CS Marks23
# Your English Marks 34
# My marks in mathematics are 12 my marks in CS are 23 and in English its 34
# __________________________________________________________

# %%
def my_first_function():
    print("Hello world!")


print(f"type: {type(my_first_function)}")

  # Calling a function
# Out:
# type: <class 'function'>

# %%
my_first_function()
# Out:
# Hello world!

# %%
def hello(name, age, class_,salary): # parametrized function
    print(f'My Name is {name} and I am {age} years old and I have a class {class_}, and I draw a salary of {salary}')

# %%
hello('Sohail', 24, 'Python', 34000)
# Out:
# My Name is Sohail and I am 24 years old and I have a class Python, and I draw a salary of 34000

# %% [markdown]
# ### Arguments

# %%
def greet_us(name1, name2):
    print(f"Hello {name1} and {name2}!")

# %%
greet_us("Sohail", "Ahmed")
# Out:
# Hello Sohail and Ahmed!

# %%
def Setting(text):
    title = text.title()
    return title

# %%
Setting('sohail ahmed')
# Out:
# 'Sohail Ahmed'

# %%
def Addition(a, b):
    c= a+b
    return c

def function_b(a,b):
    c = a-b
    return c

# %%
Addition(num1, num2)

# %%
function_b(num1, num2)

# %%
def addition(num1, num2):
    a= num1+num2;
    return a;
   
def substraction(num1, num2):
    return num1-num2; 
def multiplication(num1, num2):
    return num1*num2; 
def division(num1, num2):
    return num1/num2;

# %%
def base_func(num1, num2):
    my_func = [addition, substraction, multiplication, division]
    for i in my_func:
        print(i(num1, num2))
    return None

# %%
base_func(4,5)
# Out:
# 9
# -1
# 20
# 0.8

# %% [markdown]
# Multiplication, Subtraction, and Division

# %%
num1 = int(input("Enter num1 "))
num2 = int(input("Enter num2 "))
Addition(num1, num2)
# Out:
# Enter num1 7
# Enter num2 5
# 12

# %%
# Function with return value
def strip_and_lowercase(original):
    modified = original.strip().lower()
    return modified


uggly_string = "  MixED CaSe "
pretty = strip_and_lowercase(uggly_string)
print(f"pretty: {pretty}")
# Out:
# pretty: mixed case

# %% [markdown]
# ### Keyword arguments

# %%
my_fancy_calculation(3, 1, 5)
# Out:
# -1

# %%
my_fancy_calculation(first=77, second=1, third=450)
# Out:
# -372

# %%
def my_fancy_calculation(first, second, third):
    fifth = first + second - third
    return fifth

# %%
# # With keyword arguments you can mix the order
my_fancy_calculation(third=1, first=3, second=2)
# Out:
# 4

# %%
# # You can mix arguments and keyword arguments but you have to start with arguments
my_fancy_calculation(3, third=1, second=2)
# Out:
# 4

# %%
def data(name, age, job=None, salary=30000):
    my_data ={'name': name, 'age':age, 'Job':job, 'salary':salary}
    return my_data

# %%
data('Sohail', 24)
# Out:
# {'name': 'Sohail', 'age': 24, 'Job': None, 'salary': 30000}

# %% [markdown]
# ### Default arguments

# %%
def create_person_info(name, age, job=None, salary=300):
    info = {"name": name, "age": age, "salary": salary}

    # Add 'job' key only if it's provided as parameter
    if job:
        info.update(dict(job=job))

    return info


person1 = create_person_info("John Doe", 82)  # use default values for job and salary
person2 = create_person_info("Lisa Doe", 22, "hacker", 10000)
print(person1)
print(person2)
# Out:
# {'name': 'John Doe', 'age': 82, 'salary': 300}
# {'name': 'Lisa Doe', 'age': 22, 'salary': 10000, 'job': 'hacker'}

# %% [markdown]
# **Don't use mutable objects as default arguments!**

# %%
def append_if_multiple_of_five(number, magical_list=[]):
    if number % 5 == 0:
        magical_list.append(number)
    return magical_list

# %%
append_if_multiple_of_five(20000000000000000001)
# Out:
# [100, 100, 10, 120, 0, 200000005, 20000000000000000005]

# %%
magical_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 magical_list
#
# NameError: name 'magical_list' is not defined

# %%
print(append_if_multiple_of_five(123))
# Out:
# [100, 105]

# %%
print(append_if_multiple_of_five(123, []))
# Out:
# []

# %%
print(append_if_multiple_of_five(123))
# Out:
# [100, 105]

# %% [markdown]
# Here's how you can achieve desired behavior:

# %%
def append_if_multiple_of_five(number, magical_list=None):
    if not magical_list:
        magical_list = []
    if number % 5 == 0:
        magical_list.append(number)
    return magical_list


print(append_if_multiple_of_five(100))
print(append_if_multiple_of_five(105))
print(append_if_multiple_of_five(123))
print(append_if_multiple_of_five(123, []))
print(append_if_multiple_of_five(123))
# Out:
# [100]
# [105]
# []
# []
# []

# %% [markdown]
# ### Docstrings
# Strings for documenting your functions, methods, modules and variables.

# %%
def print_sum(val1, val2):
    """Bhai men two variables ko apas men jorr raha hn"""
    print(f"sum: {(val1 + val2)}")
    return None

# %%
print_sum(2,4)
# Out:
# sum: 6

# %%
help(print_sum)
# Out:
# Help on function print_sum in module __main__:
#
# print_sum(val1, val2)
#     Bhai men two variables ko apas men jorr raha hn

# %%
def calculate_sum(val1, val2):
    """This is a longer docstring defining also the args and the return value.

    Args:
        val1: The first parameter.
        val2: The second parameter.

    Returns:
        The sum of val1 and val2.

    """
    return val1 + val2


print(help(calculate_sum))
# Out:
# Help on function calculate_sum in module __main__:
#
# calculate_sum(val1, val2)
#     This is a longer docstring defining also the args and the return value.
#
#     Args:
#         val1: The first parameter.
#         val2: The second parameter.
#
#     Returns:
#         The sum of val1 and val2.
#
# None

# %% [markdown]
# ### [`pass`](https://docs.python.org/3/reference/simple_stmts.html#the-pass-statement) statement
# `pass` is a statement which does nothing when it's executed. It can be used e.g. a as placeholder to make the code syntatically correct while sketching the functions and/or classes of your application. For example, the following is valid Python.

# %%
# def my_function(some_argument):
#     pass

# %%
def my_function(some_argument):
    pass

# %%
sohail()
# Out:
# Sohail Ahmed Malik is now a function

# %%
print()
