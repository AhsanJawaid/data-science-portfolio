# %% [markdown]
# # Strings in Python
# ##### Strings are sequences of characters, and they are one of the most commonly used data types in Python.
#
# #### 1. Creating and Printing Strings
# ##### You can create strings using either single quotes, double quotes, or triple quotes.

# %% [markdown]
# # [Strings](https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str)

# %% [markdown]
# Logical Error---->  , Syntatic Error--->print- Print---> case sensitive
#
# data types -format of data ----> Text----> string, str, object, object, number---> interger --4, float -----5.3242, 0.45
#
# pandas, variable ---> Data hold, name, age, salary
#
# assignmnet =

# %%
name = "Sohail"
age= 24.5
qualification = 'MSDS'

# %%
text = 'Woody equal ask saw sir weeks aware decay. Entrance prospect removing we packages strictly is no smallest he. For hopes may chief get hours day rooms. Oh no turned behind polite piqued enough at. Forbade few through inquiry blushes you. Cousin no itself eldest it in dinner latter missed no.'

# %%
name =input('Enter Your name')
age  =int(input('Enter your age'))
educ =input('Enter your Education'

print(f'Hello My name is {name} and I am {age} year old, I do posses the qualification of {educ}')

# %%
text.find('sir')
# Out:
# 20

# %%
freq = text.count('sir')
freq
# Out:
# 1

# %%
salary = 34.0

# %%
type(salary)
# Out:
# float

# %%
type(age)
# Out:
# float

# %%
my_string = "Python is my favorite programming language!"

# %%
my_string
# Out:
# 'Python is my favorite programming language!'

# %%
type(my_string)
# Out:
# str

# %%
len(my_string)
# Out:
# 43

# %%
name: input
age:
salary: input
qualification:
contact: input
email:
name = input('Enter Your name')

# %%
name  = "Sohail"
contact = 9333333333
email = 'sohailahmed@gmail.com'
age = 24

# %%
bio_data = f'My Name is {name}\nAnd My Contact is {contact}\nEmail is {email}\nI am {age}years old'

# %%
print(bio_data)

# %%
# bio_date = f"My name is {}, I am {} years old, and you can contact me at {}".format(name,age,contact)

# %%
# Example 3: Using f-strings for formatted output (Python 3.6+)
name = "Sohail Ahmed"
age = 24
formatted_string = f"My name is {name} and I am {age} years old."
print(f"Formatted string: {formatted_string}")

# %%
# Example 4: Using format() method for string formatting
formatted_string_2 = "My name is {} and I am {} years old.".format(name, age)
print(f"Formatted with format(): {formatted_string_2}")

# %%
words = ['Sohai', 'Ahmed', 'Malik', 'Sukkur']

combined_words = ' '.join(words)
print(combined_words)

# %%
# !python --version
# Out:
# Python 3.11.5

# %% [markdown]
# location of values in list is the index value

# %%
full_name = ['Sohail', 'Ahmed', 'Malik', '25']

# %%
name = full_name[1] + ' '+full_name[0] +' '+ full_name[2]
age = full_name[3]

# %%
print(f'My name is {name} and I am {age} years old')
# Out:
# My name is Ahmed Sohail Malik and I am 25 years old

# %% [markdown]
# concatenation means adding strings

# %%
name = 'Sohai'+' '+ 'Ahmed'+' '+ 'Malik'+' '+ 'Sukkur'
name

# %% [markdown]
# List_data, First_name, last_name, age, salary, caste
#
# my name is last_name,+first_name, salary, caste, age,

# %%
word = "Sohail Ahmed"

first_letter = word[:-3]
first_letter

# %%
total = '100,000'

# %%
type casting --- ek type se doosre type data ko convert karenge
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 number = int(total.replace(',', ''))
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
print(f'Total sum {total}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 int(total)
#
# ValueError: invalid literal for int() with base 10: '100,000'

# %% [markdown]
# substring

# %%
word = 'Sohail Malik'

# %%
subtr = word[5:9] #start point : and end point

# %%
subtr
# Out:
# 'l Ma'

# %%
full_name =['Sohail', 'Ahmed','Malik', 'Ahmed', 'Larkana']
name = "''(-_-)'".join(full_name)
print(name)
# Out:
# Sohail''(-_-)'Ahmed''(-_-)'Malik''(-_-)'Ahmed''(-_-)'Larkana

# %%
# Example 5: Joining a list of strings into a single string
words = ["Python", "is", "fun"]
sentence = " ".join(words)
print(f"Joined string: {sentence}")
# Out:
# Joined string: Python is fun

# %%
print(f'My list has first value {full_name[0]} and Last value is {full_name[-1]}')
# Out:
# My list has first value Sohail and Last value is Larkana

# %%
print(f"Value of the list from 2 to 5 index {full_name[2:4]}")
# Out:
# Value of the list from 2 to 5 index ['Malik', 'Ahmed']

# %%
# Example 1: Accessing individual characters using indexing
word = "Python"
print(f"First character: {word[0]}")
print(f"Last character: {word[-1]}")

# %%
# Example 2: Slicing a string (substring)
print(f"First three characters: {word[:3]}")
print(f"Characters from index 2 to 4: {word[2:5]}")

# %%
# Example 3: Negative indexing (starts from the end)
print(f"Last three characters: {word[-3:]}")

# %%
# Example 5: Reversing a string using slicing
reversed_string = word[::-1]
print(f"Reversed string: {reversed_string}")

# %%
name = 'SohailAhmed-Malik'

# %%
name = name.replace('Ahmed', 'khan')

# %%
name = name.split('-')

# %%
name
# Out:
# ['Sohailkhan', 'Malik']

# %%
word = 'Sohail Malik'

# %%
word = word.replace('Malik', 'Ahmed')
word

# %%
word = 'Sohail Malik'
word = word.split(' ')
word

# %%
# Example 3: replace() - replacing parts of a string
replaced_string = original_string.replace("Fun", "awesome")
print(f"Replaced string: {replaced_string}")

# %%
# Example 4: split() - splitting a string into a list of substrings
split_string = "Python,Java,C++".split(",")
print(f"Split string: {split_string}")

# %%
text = 'Sukkur IBA University is a public sector university. IBA is in sukkur region'

# %%
iba = text.find('IBA')
frequency = text.count('IBA')
frequency
# Out:
# 2

# %%
# Example 5: find() and count() - finding substrings and counting occurrences
text = "Python is a great programming language. Python is popular."
print(f"First occurrence of 'Python': {text.find('Python')}")
print(f"Count of 'Python': {text.count('Python')}")

# %% [markdown]
# mutable or unmutable, try- catch method, exception handling

# %%
name = "sohail"

try:
    name[0] = "S"
except TypeError as e:
    print(f"Error: {e}")
# Out:
# Error: 'str' object does not support item assignment

# %%
name.replace('s','S')
# Out:
# 'S'

# %%
name
# Out:
# 'S'

# %%
# 5. String Immutability
# Strings in Python are immutable, meaning they cannot be changed after they are created.

# Example: Attempting to modify a string will result in an error
immutable_string = "Immutable"
try:
    immutable_string[0] = "i"
except TypeError as e:
    print(f"Error: {e}")

# %%
text = 'FAST NUCES Karachi is located in the Hub of Karachi, it is the most prominent unive of Karachi'

location  = text.find('Karachi')
freq = text.count('Karachi')

# %%
name = "sohail"

# %%
name.replace('s', 'S')
# Out:
# 'Sohail'

# %%
word = 'sohail'

word = 'S'+word[1:]
word
# Out:
# 'Sohail'

# %%
# Instead, you can create a new string
new_string = "i" + immutable_string[1:]
print(f"Modified string: {new_string}")

# %%
# 6. String Comparisons
# Strings can be compared using relational operators.

# Example 1: Checking equality
print(f"Are 'Python' and 'python' the same? {'Python' == 'python'}")

# %%
word = 'sohail AHMED'

word.title()
# Out:
# 'Sohail Ahmed'

# %%
# Example 2: Case-insensitive comparison
print(f"Case-insensitive comparison: {'Python'.lower() == 'python'.lower()}")

# %%
word = 'Sohail Ahmed'
word.endswith('S')
# Out:
# False

# %%
# Example 4: Checking if a string starts or ends with a substring
filename = "example.py"
print(f"Does filename start with 'ex'? {filename.startswith('ex')}")
print(f"Does filename end with '.py'? {filename.endswith('.py')}")

# %%
# Example 5: Checking if a string contains only digits
numeric_string = "12345"
print(f"Is the string numeric? {numeric_string.isdigit()}")

# %% [markdown]
# ### Respecting [PEP8](https://www.python.org/dev/peps/pep-0008/#maximum-line-length) with long strings

# %%
long_story = (
   "Sukkur IBA University is one of the top public sector university\nIt has almost 8 Departments including, CS,SE, BBA, A&F, BBA-Ag \nIt is located in the hub of Sukkur City, on Nisar Ahmed Sidiqui Road"
)
print(long_story)

# %% [markdown]
# ## `str.replace()`

# %% [markdown]
# If you don't know how it works, you can always check the `help`:

# %%
help(str.replace)

# %% [markdown]
# This will not modify `my_string` because replace is not done in-place.

# %%
my_string.replace("a", "?")
print(my_string)

# %% [markdown]
# You have to store the return value of `replace` instead.

# %%
my_modified_string = my_string.replace("is", "will be", 1)
print(my_modified_string)

# %% [markdown]
# ## f-strings

# %%
first_name = "Sohail"
last_name = "Ahmed"
age = 24
print(f"My name is {first_name} {last_name}, you can call me {first_name}.")
print(f"I'm {age} years old.")

# %%
print(f"Use '=' to also print the variable name like this: {age=}")

# %% [markdown]
# ## `str.join()`

# %%
pandas = "pandas"
numpy = "numpy"
requests = "requests"
cool_python_libs = ", ".join([pandas, numpy, requests])

# %%
print(f"Some cool python libraries: {cool_python_libs}")

# %% [markdown]
# Alternative (not as [Pythonic](http://docs.python-guide.org/en/latest/writing/style/#idioms) and [slower](https://waymoot.org/home/python_string/)):

# %%
cool_python_libs = pandas + ", " + numpy + ", " + requests
print(f"Some cool python libraries: {cool_python_libs}")

cool_python_libs = pandas
cool_python_libs += ", " + numpy
cool_python_libs += ", " + requests
print(f"Some cool python libraries: {cool_python_libs}")

# %% [markdown]
# ## `str.upper(), str.lower(), str.title()`

# %%
mixed_case = "PyTHoN hackER"

# %%
mixed_case.upper()

# %%
mixed_case.lower()

# %%
mixed_case.title()

# %%
word = '   sohail      '

# %%
word.strip()

# %% [markdown]
# ## `str.strip()`

# %% [markdown]
# The strip() method removes any leading, and trailing whitespaces. Leading means at the beginning of the string, trailing means at the end. You can specify which character(s) to remove, if not, any whitespaces will be removed.

# %%
ugly_formatted = " \n \t Some story to tell."
stripped = ugly_formatted.strip()

print(f"ugly: {ugly_formatted}")
print(f"stripped: {stripped}")

# %%
txt = ",,,,,rrttgg.....banana....rrr"

x = txt.strip(",.grt")

print(x)

# %% [markdown]
# ## str.split()

# %%
sentence = "three different words"
words = sentence.split()
print(words)

# %%
type(words)

# %%
secret_binary_data = "01001,101101,11100000"
binaries = secret_binary_data.split(",")
print(binaries)

# %% [markdown]
# ## Calling multiple methods in a row

# %%
ugly_mixed_case = "   ThIS LooKs BAd "
pretty = ugly_mixed_case.strip().lower().title().replace("bad", "good")
print(pretty)

# %% [markdown]
# Note that execution order is from left to right. Thus, this won't work:

# %%
pretty = ugly_mixed_case.replace("bad", "good").strip().lower()
print(pretty)

# %% [markdown]
# ## [Escape characters](http://python-reference.readthedocs.io/en/latest/docs/str/escapes.html#escape-characters)

# %%
two_lines = "First line\nSecond line"
print(two_lines)

# %%
indented = "\tThis will be indented"
print(indented)

# %%
name

# %% [markdown]
# # Summary:
# 1.  Strings can be created using single, double, or triple quotes.
# 2.  You can manipulate strings using concatenation, repetition, and various string methods.
# 3.  Strings are immutable, meaning they cannot be changed after they are created.
# 4.  String indexing and slicing allows for extracting substrings or individual characters.
